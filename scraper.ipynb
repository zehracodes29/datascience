# %%
from dputils.scrape import Scraper,Tag

# %%
url='https://www.flipkart.com/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYO7HQ2L&marketplace=FLIPKART&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=b_1_1&otracker=browse&fm=organic&iid=e853967e-5569-4744-9f1f-ca145b8955fc.MOBGTAGPAQNVFZZY.SEARCH&ppt=browse&ppn=browse&ssid=xu4xthww400000001712381920665'
sc=Scraper(url)
# Out:
# Selecting a random User-Agent...
# Randomly picked browser: Edge
# Randomly picked operating system: Windows
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐
# User agent:  {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 Edg/94.0.992.50'}
# Cookies:  {'session-id': '', 'session-id-time': '', 'session-token': ''}
# url:  https://www.flipkart.com/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYO7HQ2L&marketplace=FLIPKART&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=b_1_1&otracker=browse&fm=organic&iid=e853967e-5569-4744-9f1f-ca145b8955fc.MOBGTAGPAQNVFZZY.SEARCH&ppt=browse&ppn=browse&ssid=xu4xthww400000001712381920665
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐

# %%
title=Tag('span' , cls='B_NuCI')
price=Tag(cls='_30jeq3_16Jk6d')
sc.get_page_data(title=title,
                 price=price,
                 rating_count=Tag('span',cls='_2_R_DZ'))
# Out:
# {'title': 'Apple iPhone 15 (Blue, 128 GB)',
#  'price': None,
#  'rating_count': '21,711 Ratings\xa0&\xa01,503 Reviews'}

# %%
url2='https://www.amazon.in/adidas-ASTELLAR-CBLACK-FTWWHT-Running/dp/B0CPVN7FZC/ref=s9_acsd_al_ot_cv2_3_t?_encoding=UTF8&pf_rd_m=A21TJRUUN4KGV&pf_rd_s=merchandised-search-5&pf_rd_r=MFQ330NWE2417FSY5E1W&pf_rd_p=3c713536-a704-4112-982f-217a853a9084&pf_rd_t=&pf_rd_i=1983518031'
sc=Scraper(url2)
# Out:
# Selecting a random User-Agent...
# Randomly picked browser: Chrome
# Randomly picked operating system: Windows
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐
# User agent:  {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36'}
# Cookies:  {'session-id': '', 'session-id-time': '', 'session-token': ''}
# url:  https://www.amazon.in/adidas-ASTELLAR-CBLACK-FTWWHT-Running/dp/B0CPVN7FZC/ref=s9_acsd_al_ot_cv2_3_t?_encoding=UTF8&pf_rd_m=A21TJRUUN4KGV&pf_rd_s=merchandised-search-5&pf_rd_r=MFQ330NWE2417FSY5E1W&pf_rd_p=3c713536-a704-4112-982f-217a853a9084&pf_rd_t=&pf_rd_i=1983518031
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐

# %%
URL='https://www.flipkart.com/cameras/dslr-mirrorless/pr?sid=jek,p31,trv&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_097479f5-5ae7-440b-ac0b-e32fa9ef6e3f_1_372UD5BXDFYS_MC.0KU83APBTPQK&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Electronics~Cameras%2B%2526%2BAccessories~DSLR%2B%2526%2BMirrorless_0KU83APBTPQK&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&cid=0KU83APBTPQK'
sc=Scraper(URL)
# Out:
# Selecting a random User-Agent...
# Randomly picked browser: Chrome
# Randomly picked operating system: Windows
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐
# User agent:  {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36'}
# Cookies:  {'session-id': '', 'session-id-time': '', 'session-token': ''}
# url:  https://www.flipkart.com/cameras/dslr-mirrorless/pr?sid=jek,p31,trv&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_097479f5-5ae7-440b-ac0b-e32fa9ef6e3f_1_372UD5BXDFYS_MC.0KU83APBTPQK&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Electronics~Cameras%2B%2526%2BAccessories~DSLR%2B%2526%2BMirrorless_0KU83APBTPQK&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&cid=0KU83APBTPQK
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐

# %%
result = sc.get_repeating_page_data(
    target=Tag('body'),
    items=Tag('a',cls='_1fQZEK'),
    title=Tag(cls='_4rR01T'),
    price=Tag(cls='_30jeq3 _1_WHN1'),
    oprice=Tag(cls='_3I9_wc _27UcVY'),
    rating_n_review=Tag(cls='gUuXy'),
    

)

# %%
import pandas as pd
pd.DataFrame(result)
# Out:
#                                                 title      price     oprice  \
# 0   FUJIFILM X Series X-T4 Mirrorless Camera Body ...  ₹1,26,989  ₹1,54,999
# 1    NIKON D7500 DSLR Camera Body with 18-140 mm Lens    ₹78,990    ₹94,950
# 2   Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...    ₹34,490    ₹35,995
# 3    Canon EOS 200D II DSLR Camera EF-S18-55mm IS STM    ₹55,990    ₹68,995
# 4   Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...    ₹39,990    ₹47,995
# 5   SONY Alpha ILCE-6400 APS-C Mirrorless Camera B...    ₹65,489    ₹80,490
# 6   SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...    ₹74,489    ₹90,990
# 7   SONY Alpha ILCE-6100Y APS-C Mirrorless Camera ...    ₹73,989    ₹89,990
# 8   SONY Alpha ILCE-6100L APS-C Mirrorless Camera ...    ₹61,489    ₹75,990
# 9   SONY Alpha ILCE-7M3K Full Frame Mirrorless Cam...  ₹1,41,489  ₹1,61,490
# 10  SONY ZV-E10L Mirrorless Camera Body with 1650 ...    ₹61,489    ₹69,990
# ...
